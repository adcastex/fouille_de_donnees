# %% [markdown]
# # Pre processing

# %% [markdown]
# #### over sampling : (ajout)
# Random, SMOTE, BorderSMOTE, Adasyn
# + lib : SMOTENC, Borderline smote, SMOTEN, Kmeans smote, SVM smote

# %% [markdown]
# https://imbalanced-learn.org/stable/references/over_sampling.html

# %%
from imblearn.over_sampling import SMOTE, BorderlineSMOTE, ADASYN

# %% [markdown]
# #### Under sampling : (enlever)
#
# random, Tomek Link, NearMiss, Condensed Nearest neighbor, Edited NN, Onde sided selection

# %% [markdown]
# https://imbalanced-learn.org/stable/references/under_sampling.html

# %%
from imblearn.under_sampling import TomekLinks

# %% [markdown]
# #### cost sensitive
#
# Matrice de coût à faire avant, matrice de confusion
# class_weight -> parametre à modifier lors de la creation du classifier
#
# (mettre en avant les plus grosses fraudes)

# %%
#exemple

from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(C=1,class_weight={0:1,1:1},random_state=0)

# %% [markdown]
# # Algos à utiliser

# %% [markdown]
# ### Non supervisé
#
# k-means, clustering hierarchique,  auto encodeur

# %% [markdown]
# ### supervisé
#
# decision tree, random forest, gradient boosting, nearest neighbors, RNN, SVM(lineaire et non lineaire )(noyau gaussien ),analyse discriminante, boosting

# %% [markdown]
# #### Boosting
#
# Boosting param
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html#sklearn.ensemble.AdaBoostClassifier
#
# Gradient tree boosting
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html#sklearn-ensemble-gradientboostingclassifier
#
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingClassifier.html#sklearn.ensemble.HistGradientBoostingClassifier

# %% [markdown]
# # Post traitement

# %% [markdown]
# Faire du bagging
